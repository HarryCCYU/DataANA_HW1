# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


Data = pd.read_csv('./Reviews.csv')
Data = Data[:10000]

# %%
plt.figure(figsize=(12,10))
sns.set()
fig = sns.heatmap(Data.corr(), vmax=0.6, square=True, annot=True)
